# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
# %matplotlib inline
from sklearn import preprocessing

# %%
plt.rc('font', family='NanumGothic')

# %%
mang_tourfavor = pd.read_csv("/Users/jaeyoungcho/Desktop/2020 금융 빅데이터 챌린지-공모전데이터/데이터/망고플레이트/관광지인기식당.csv", sep=",", encoding="CP949")
mang_generalinfo = pd.read_csv("/Users/jaeyoungcho/Desktop/2020 금융 빅데이터 챌린지-공모전데이터/데이터/망고플레이트/식당기본정보.csv", sep=",", encoding="CP949")
mang_forefavor = pd.read_csv("/Users/jaeyoungcho/Desktop/2020 금융 빅데이터 챌린지-공모전데이터/데이터/망고플레이트/외국인인기식당.csv", sep=",", encoding="CP949")
mang_festivallist = pd.read_csv("/Users/jaeyoungcho/Desktop/2020 금융 빅데이터 챌린지-공모전데이터/데이터/망고플레이트/축제탑리스트.csv", sep=",", encoding="CP949")
mang_nativefavor = pd.read_csv("/Users/jaeyoungcho/Desktop/2020 금융 빅데이터 챌린지-공모전데이터/데이터/망고플레이트/현지인인기식당.csv", sep=",", encoding="CP949")

# %%
mang_tourfavor
# Out:
#              식당ID     식당명       지점명         대표전화번호                 식당지번주소  \
# 0      AiNn-Uoxb2     오페뜨     서래마을점    02-532-7876       서울시 서초구 반포동 91-7
# 1      VEESZVLNxX     새벽집      청담동점    02-546-5739     서울시 강남구 청담동 129-10
# 2      0R0LaY6p0k     장사랑       NaN    02-546-9994     서울시 강남구 신사동 624-17
# 3      Ok6wpk-VcG    영천영화       청담점   02-3442-0381      서울시 강남구 청담동 50-13
# 4      Tvr9CwDGB5    서초면옥      교대본점    02-522-1422     서울시 서초구 서초동 1557-7
# ..            ...     ...       ...            ...                    ...
# 995  ZrXjFSqkbN82  버거스테이지       NaN  070-8807-5940   강원도 양양군 현남면 시변리 10-4
# 996  mrP33_5jgw4w   점보씨푸드       도곡점    02-578-6655      서울시 강남구 도곡동 467-7
# 997  nnGrPISUCCr4   베이커리궁       NaN   033-734-9700     강원도 원주시 행구동 1329-1
# 998  HU47TcKp2W3p   호두잣과자  가평휴게소하행점            NaN  경기도 가평군 설악면 미사리 149-4
# 999  1NqkXDpH-d6N     에테르       NaN   051-263-5055     부산시 영도구 영선동4가 1102
#
#                      식당도로명주소    식당위도좌표값     식당경도좌표값 1인당가격만원단위구간값 음식대분류명  ...  \
# ...

# %%
mang_generalinfo
# Out:
#         기준년월          식당ID       식당명    지점명         대표전화번호  \
# 0     202004    930AnUvy01     좋은흑염소    NaN   033-255-5579
# 1     202004    99GVb8kY5k      낭만국시    NaN   033-252-6255
# 2     202004    oJjxye3Gt6     리버스토리    NaN  070-4252-4540
# 3     202004    k8Rnj-EDVL       산마루    NaN   033-241-7783
# 4     202004    MCnsgZiqXN      로케로케    NaN  010-8243-0282
# ...      ...           ...       ...    ...            ...
# 9563  202004    w72lM5F0uz  시조명동닭한마리    NaN   02-2275-3125
# 9564  202004  2wtiscsaQaS0      팡파미유  중앙시장점  010-8297-7995
# 9565  202004  LNqeadyLUkt8      카쿠레가    NaN  070-8865-6578
# 9566  202004  o8nWULk5F_aa      라또래요    NaN  010-5755-4156
# 9567  202004  s0fQLub7xnXb     돌체테리아    NaN   033-643-6688
#
#                     식당지번주소                식당도로명주소    식당위도좌표값     식당경도좌표값  \
# 0         강원도 춘천시 퇴계동 1144         강원도 춘천시 남춘천길 5  37.865906  127.727455
# 1       강원도 춘천시 죽림동 11-121      강원도 춘천시 명동길29번길 3  37.878124  127.725922
# ...

# %%
mang_forefavor
# Out:
#              식당ID        식당명        지점명         대표전화번호                 식당지번주소  \
# 0    2cc9iN8lw1DL      잘빠진메밀       익선동점  070-4531-1214         서울시 종로구 묘동 3-1
# 1    OuW2wciGeOqZ         포가        NaN  010-8899-5900      서울시 마포구 연남동 228-2
# 2    TjuaiXuYUsAB        루소랩        정동점    02-772-9935         서울시 중구 정동 17-4
# 3      1euTBie3du        유유안  포시즌스호텔 서울   02-6388-5500         서울시 종로구 당주동 30
# 4      AThr72-XDZ  고분옥할머니순두부        NaN   033-652-1897     강원도 강릉시 초당동 308-11
# ..            ...        ...        ...            ...                    ...
# 995    04yIMS1Dsk       운정이네         본점   064-738-3883     제주 서귀포시 중문동 1239-5
# 996  jjVwur-qXFb8        양복점        NaN   032-515-1012     인천시 부평구 부평동 207-35
# 997        #NAME?     돌담너머바다        NaN  010-5344-5527  제주 제주시 한경면 판포리 2881-3
# 998  fmTJWgXvp-T7     이태원소주집        NaN  070-7808-3789     서울시 용산구 이태원동 457-3
# 999    n0QUPpGOPW         무월        NaN    02-555-3060     서울시 강남구 역삼동 811-12
#
# ...

# %%
mang_festivallist
# Out:
#       탑리스트ID        탑리스트타이틀                탑리스트설명  탑리스트내순위          식당ID  \
# 0       1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        1  yCzfx7lxPG9N
# 1       1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        2    mZC6I-NXse
# 2       1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        3    eZNFlbAgzP
# 3       1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        4    lKrI9NWcRu
# 4       1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        5    K9X9Uwxw__
# ...      ...            ...                   ...      ...           ...
# 996     1836  평촌 맛집 베스트 10곳         평촌이 맛집 불모지라구?        6    2EHQiZDL36
# 997     1836  평촌 맛집 베스트 10곳         평촌이 맛집 불모지라구?        7  PYs0O7aCKbIn
# 998     1836  평촌 맛집 베스트 10곳         평촌이 맛집 불모지라구?        8    Rum0PNml8a
# 999     1836  평촌 맛집 베스트 10곳         평촌이 맛집 불모지라구?        9    ntnz7Lo2kp
# 1000    1836  평촌 맛집 베스트 10곳         평촌이 맛집 불모지라구?       10    N7FOc8cUu2
#
#              식당명        지점명         대표전화번호                  식당지번주소  \
# ...

# %%
mang_nativefavor
# Out:
#              식당ID               식당명  지점명        대표전화번호                 식당지번주소  \
# 0      WhwWZh7_-V          우동명가기리야마  NaN   02-567-0068     서울시 강남구 역삼동 824-11
# 1      kkTSEK1nWp               봉밀가  NaN   02-546-2305        서울시 강남구 삼성동 8-1
# 2      J4rryjvWN5             쟝블랑제리  NaN   02-889-5170     서울시 관악구 봉천동 1660-7
# 3      zHeV7AfPBr          티앙팡오후의홍차  NaN   02-364-4196     서울시 서대문구 대현동 54-28
# 4    adFAd5nyITV0             광화문국밥  NaN   02-738-5688         서울시 중구 정동 1-48
# ..            ...               ...  ...           ...                    ...
# 994  2jbK-LWJXVs0                비밀  NaN   02-313-0877     서울시 서대문구 대현동 27-46
# 995    5O7gFT2hlY  싱싱오동도산아나고꼼장어숯불구이  NaN   02-532-9679     서울시 서초구 방배동 3001-2
# 996    q20qRCRIIS              허브족발   본점  02-2633-4339  서울시 영등포구 당산동6가 237-38
# 997    v3HPIb2VWJ            화진포막국수  NaN   02-478-1539      서울시 강동구 성내동 559-9
# 998  9TtK_cdvAJV6               우라만  NaN   02-797-8399    서울시 용산구 이태원동 261-41
#
# ...

# %%
temp_tour = copy.copy(mang_tourfavor)
temp_tour = temp_tour[temp_tour.columns[17:21]]
temp_tour
# Out:
#      식당평점값  식당리뷰수    식당조회수 식당방문희망건수
# 0      3.8     30    8,904      139
# 1      3.9    185   71,798    1,859
# 2      3.7    115  101,644    2,885
# 3      4.3     49   54,606    1,450
# 4      3.9     55   63,023    1,269
# ..     ...    ...      ...      ...
# 995    3.8      7    5,484       61
# 996    3.8     17   21,121      691
# 997    3.9      9    4,119      163
# 998    3.8      4    2,511       20
# 999    3.6      5    1,458       46
#
# [1000 rows x 4 columns]

# %%
temp_tour.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_de27bafe_0d28_11eb_b8d0_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_de27bafe_0d28_11eb_b8d0_acde48001122row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_de27bafe_0d28_11eb_b8d0_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_de27bafe_0d28_11eb_b8d0_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_de27bafe_0d28_11eb_b8d0_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >식당평점값</th>        <th class="col_heading level0 col1" >식당리뷰수</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de27bafe_0d28_11eb_b8d0_acde48001122level0_row0" class="row_heading level0 row0" >식당평점값</th>
# ...

# %%
temp_tour.isnull().sum()
# Out:
# 식당평점값       157
# 식당리뷰수         0
# 식당조회수         0
# 식당방문희망건수      0
# dtype: int64

# %%
temp_tour['식당조회수'].unique()
# Out:
# array(['8,904', '71,798', '101,644', '54,606', '63,023', '76,763',
#        '32,168', '196,222', '44,036', '22,759', '20,551', '54,734',
#        '21,762', '295,019', '53,283', '72,688', '101,561', '217,418',
#        '66,231', '95,270', '52,927', '15,862', '23,836', '40,717',
#        '95,179', '93,406', '68,879', '10,036', '112,274', '23,146',
#        '21,645', '81,389', '78,519', '76,702', '105,792', '167,741',
#        '150,363', '121,237', '91,625', '30,127', '51,919', '11,167',
#        '38,753', '16,783', '16,388', '26,202', '132,278', '19,177',
#        '29,289', '122,362', '19,813', '41,478', '94,860', '33,317',
#        '32,668', '17,034', '246,919', '161,949', '41,385', '13,578',
#        '68,834', '34,718', '54,446', '12,429', '8,045', '10,895',
#        '58,621', '117,209', '85,522', '18,167', '15,989', '30,027',
#        '53,799', '5,993', '16,801', '57,203', '21,188', '49,651',
#        '79,110', '62,171', '49,419', '25,173', '31,154', '52,109',
# ...

# %%
alist = []
for i in temp_tour['식당조회수']:
    alist.append(i.replace(",",""))

temp_tour['식당조회수'] = alist
temp_tour
# Out:
#      식당평점값  식당리뷰수   식당조회수 식당방문희망건수
# 0      3.8     30    8904      139
# 1      3.9    185   71798    1,859
# 2      3.7    115  101644    2,885
# 3      4.3     49   54606    1,450
# 4      3.9     55   63023    1,269
# ..     ...    ...     ...      ...
# 995    3.8      7    5484       61
# 996    3.8     17   21121      691
# 997    3.9      9    4119      163
# 998    3.8      4    2511       20
# 999    3.6      5    1458       46
#
# [1000 rows x 4 columns]

# %%
alist = []

for i in temp_tour['식당방문희망건수']:
    b = i.replace(",","")
    b = int(b)
    alist.append(i.replace(",",""))

temp_tour['식당방문희망건수'] = alist
temp_tour
# Out:
#      식당평점값  식당리뷰수   식당조회수 식당방문희망건수
# 0      3.8     30    8904      139
# 1      3.9    185   71798     1859
# 2      3.7    115  101644     2885
# 3      4.3     49   54606     1450
# 4      3.9     55   63023     1269
# ..     ...    ...     ...      ...
# 995    3.8      7    5484       61
# 996    3.8     17   21121      691
# 997    3.9      9    4119      163
# 998    3.8      4    2511       20
# 999    3.6      5    1458       46
#
# [1000 rows x 4 columns]

# %%
temp_tour.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_decc47cc_0d28_11eb_b2f6_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_decc47cc_0d28_11eb_b2f6_acde48001122row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_decc47cc_0d28_11eb_b2f6_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_decc47cc_0d28_11eb_b2f6_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_decc47cc_0d28_11eb_b2f6_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >식당평점값</th>        <th class="col_heading level0 col1" >식당리뷰수</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_decc47cc_0d28_11eb_b2f6_acde48001122level0_row0" class="row_heading level0 row0" >식당평점값</th>
# ...

# %%
mang_tourfavor.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ded9f502_0d28_11eb_af8a_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row0_col1 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row0_col2 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row0_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row1_col0 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ded9f502_0d28_11eb_af8a_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
mang_forefavor.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_dee6c168_0d28_11eb_9ef8_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row0_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row0_col2 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row0_col3 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_dee6c168_0d28_11eb_9ef8_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
mang_nativefavor.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_def35e70_0d28_11eb_8110_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row0_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_def35e70_0d28_11eb_8110_acde48001122row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
mang_festivallist.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col1 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col2 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col4 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row0_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_df015b9c_0d28_11eb_9ff0_acde48001122row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
mang_generalinfo.corr().style.background_gradient(cmap='coolwarm')
# Out:
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/pandas/io/formats/style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/pandas/io/formats/style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_df118bfa_0d28_11eb_a48c_acde48001122row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_df118bfa_0d28_11eb_a48c_acde48001122row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_df118bfa_0d28_11eb_a48c_acde48001122row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_df118bfa_0d28_11eb_a48c_acde48001122row0_col3 {
#             background-color:  #000000;
# ...

# %%
temp_tour.plot()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49885 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45817 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jaeyoungcho/opt/anaconda3/envs/BigContest/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

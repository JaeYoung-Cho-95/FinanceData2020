# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import preprocessing

# %%
plt.rc('font', family='NanumGothic')

# %%
mang_tourfavor = pd.read_csv("D:/프로그래밍/2020.9.금융빅데이터/망고플레이트/관광지인기식당.csv", sep=",", encoding="CP949")
mang_generalinfo = pd.read_csv("D:/프로그래밍/2020.9.금융빅데이터/망고플레이트/식당기본정보.csv", sep=",", encoding="CP949")
mang_forefavor = pd.read_csv("D:/프로그래밍/2020.9.금융빅데이터/망고플레이트/외국인인기식당.csv", sep=",", encoding="CP949")
mang_festivallist = pd.read_csv("D:/프로그래밍/2020.9.금융빅데이터/망고플레이트/축제탑리스트.csv", sep=",", encoding="CP949")
mang_nativefavor = pd.read_csv("D:/프로그래밍/2020.9.금융빅데이터/망고플레이트/현지인인기식당.csv", sep=",", encoding="CP949")

# %%
mang_tourfavor.head(3)
# Out:
#          식당ID  식당명    지점명       대표전화번호              식당지번주소  \
# 0  AiNn-Uoxb2  오페뜨  서래마을점  02-532-7876    서울시 서초구 반포동 91-7
# 1  VEESZVLNxX  새벽집   청담동점  02-546-5739  서울시 강남구 청담동 129-10
# 2  0R0LaY6p0k  장사랑    NaN  02-546-9994  서울시 강남구 신사동 624-17
#
#                  식당도로명주소    식당위도좌표값     식당경도좌표값 1인당가격만원단위구간값 음식대분류명  ...  \
# 0       서울특별시 서초구 서래로 32  37.497926  126.998425        만원 미만     카페  ...
# 1   서울특별시 강남구 도산대로101길 6  37.525495  127.052763       4만원 이상     한식  ...
# 2  서울특별시 강남구 언주로165길 7-6  37.525478  127.032324       만원-2만원     한식  ...
#
#   휴식시간내용 최종주문가능시간값 식당휴일내용     메인메뉴내용 식당평점값 식당리뷰수    식당조회수  식당방문희망건수  \
# 0    NaN       NaN    NaN         카페   3.8    30    8,904       139
# 1    NaN       NaN    NaN  소고기구이 전문점   3.9   185   71,798     1,859
# 2    NaN       NaN    NaN        한정식   3.7   115  101,644     2,885
#
#          대상년월   센터코드
# 0  2020-08-19  BBP12
# 1  2020-08-19  BBP12
# 2  2020-08-19  BBP12
#
# [3 rows x 23 columns]

# %%
mang_generalinfo.head(3)
# Out:
#      기준년월        식당ID    식당명  지점명         대표전화번호               식당지번주소  \
# 0  202004  930AnUvy01  좋은흑염소  NaN   033-255-5579     강원도 춘천시 퇴계동 1144
# 1  202004  99GVb8kY5k   낭만국시  NaN   033-252-6255   강원도 춘천시 죽림동 11-121
# 2  202004  oJjxye3Gt6  리버스토리  NaN  070-4252-4540  강원도 춘천시 서면 신매리 67-1
#
#                식당도로명주소    식당위도좌표값     식당경도좌표값 1인당가격만원단위구간값  ... 휴식시간내용  \
# 0       강원도 춘천시 남춘천길 5  37.865906  127.727455          NaN  ...    NaN
# 1    강원도 춘천시 명동길29번길 3  37.878124  127.725922          NaN  ...    NaN
# 2  강원도 춘천시 서면 박사로 1210  37.916904  127.712669          NaN  ...    NaN
#
#   최종주문가능시간값 식당휴일내용 메인메뉴내용 식당평점값 식당리뷰수  식당조회수  식당방문희망건수          적재일시   센터코드
# 0       NaN    NaN    NaN   NaN   0.0  794.0       0.0  2.020080e+13  BBP12
# 1       NaN    NaN    NaN   NaN   0.0  810.0       2.0  2.020080e+13  BBP12
# 2       NaN    NaN    NaN   NaN   0.0  532.0       0.0  2.020080e+13  BBP12
#
# [3 rows x 24 columns]

# %%
mang_forefavor.head(3)
# Out:
#            식당ID    식당명   지점명         대표전화번호             식당지번주소  \
# 0  2cc9iN8lw1DL  잘빠진메밀  익선동점  070-4531-1214     서울시 종로구 묘동 3-1
# 1  OuW2wciGeOqZ     포가   NaN  010-8899-5900  서울시 마포구 연남동 228-2
# 2  TjuaiXuYUsAB    루소랩   정동점    02-772-9935     서울시 중구 정동 17-4
#
#                 식당도로명주소    식당위도좌표값     식당경도좌표값 1인당가격만원단위구간값 음식대분류명  ...  \
# 0    서울특별시 종로구 율곡로8길 73  37.574039  126.991501        만원 미만     한식  ...
# 1  서울특별시 마포구 성미산로 190-4  37.562852  126.926054        만원 미만     중식  ...
# 2       서울특별시 중구 정동길 17  37.567039  126.970494        만원 미만     카페  ...
#
#           휴식시간내용 최종주문가능시간값 식당휴일내용          메인메뉴내용 식당평점값 식당리뷰수   식당조회수  \
# 0  15:00 - 17:00       NaN      일  메밀국수 / 막국수 전문점   3.9    36  37,250
# 1  15:00 - 17:30       NaN      월           일반 중식   4.4    59  91,916
# 2            NaN       NaN    NaN              카페   4.0    57  35,530
#
#    식당방문희망건수        대상년월   센터코드
# 0     1,580  2020-08-19  BBP12
# 1     3,666  2020-08-19  BBP12
# 2     1,036  2020-08-19  BBP12
#
# ...

# %%
mang_festivallist.head(3)
# Out:
#    탑리스트ID        탑리스트타이틀                탑리스트설명  탑리스트내순위          식당ID  \
# 0    1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        1  yCzfx7lxPG9N
# 1    1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        2    mZC6I-NXse
# 2    1583  가평 맛집 베스트 15곳  먹고 즐기기에 가평만 한 곳이 없지!        3    eZNFlbAgzP
#
#           식당명  지점명         대표전화번호                 식당지번주소  \
# 0         명월집  NaN  010-2737-8333  경기도 가평군 청평면 청평리 714-4
# 1  설악막국수춘천닭갈비  NaN   031-584-9231  경기도 가평군 설악면 신천리 569-3
# 2    신숙희진골막국수  NaN   031-584-3337    경기도 가평군 상면 임초리 32-9
#
#                  식당도로명주소  ...  휴식시간내용  최종주문가능시간값 식당휴일내용          메인메뉴내용 식당평점값  \
# 0     경기도 가평군 청평면 호반로 38  ...     NaN        NaN    NaN         불고기 전문점   4.4
# 1  경기도 가평군 설악면 신천중앙로 161  ...     NaN        NaN    NaN         닭갈비 전문점   4.2
# 2     경기도 가평군 상면 청군로 628  ...     NaN        NaN      화  메밀국수 / 막국수 전문점   4.2
#
#   식당리뷰수   식당조회수 식당방문희망건수        대상년월   센터코드
# 0     8  15,131      337  2020-08-19  BBP12
# 1    21  34,121      467  2020-08-19  BBP12
# ...

# %%
mang_nativefavor.head(3)
# Out:
#          식당ID       식당명  지점명       대표전화번호              식당지번주소  \
# 0  WhwWZh7_-V  우동명가기리야마  NaN  02-567-0068  서울시 강남구 역삼동 824-11
# 1  kkTSEK1nWp       봉밀가  NaN  02-546-2305     서울시 강남구 삼성동 8-1
# 2  J4rryjvWN5     쟝블랑제리  NaN  02-889-5170  서울시 관악구 봉천동 1660-7
#
#                 식당도로명주소    식당위도좌표값     식당경도좌표값 1인당가격만원단위구간값 음식대분류명  ...  \
# 0  서울특별시 강남구 강남대로84길 23  37.497002  127.030393        만원 미만     일식  ...
# 1     서울특별시 강남구 선릉로 664  37.515981  127.042396        만원 미만     한식  ...
# 2     서울특별시 관악구 낙성대역길 8  37.477148  126.961962        만원 미만     카페  ...
#
#                                  휴식시간내용 최종주문가능시간값 식당휴일내용    메인메뉴내용 식당평점값  \
# 0  월-금: 14:30 - 17:30, 토: 15:30 - 17:00       NaN      일    우동 전문점   4.2
# 1                         15:00 - 17:00       NaN      일  평양냉면 전문점   4.3
# 2                                   NaN       NaN    NaN      베이커리   4.1
#
#   식당리뷰수    식당조회수  식당방문희망건수        대상년월   센터코드
# 0   193  182,143     5,337  2020-08-19  BBP12
# ...
